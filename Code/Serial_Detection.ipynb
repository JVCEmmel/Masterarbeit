# %% [markdown]
# # Serial Detection
#
# In diesem Notebook wird der Code besprochen, der nötig ist, damit Bilder in einem Ordner von einem untrainierten Neuronalen Netz klassifiziert werden können.

# %%
import torch, torchvision
import detectron2

from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import os, json, cv2, random, time

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
path = "/home/julius/PowerFolders/Masterarbeit/Abbildungen/"

# %%
image_list = sorted([image for image in os.listdir(path) if image.lower().endswith(".jpg")])
print(len(image_list))
# Out:
# 68

# %%
output_path = path + "detections/"
if not os.path.isdir(output_path):
    os.mkdir(output_path)
output_path = output_path + "{}/".format(time.strftime("%d,%m,%Y-%H,%M,%S"))
if not os.path.isdir(output_path):
    os.mkdir(output_path)

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")

# %%
for element in image_list:
    picture = cv2.imread(path + element)
    predictor = DefaultPredictor(cfg)
    outputs = predictor(picture)

    print(outputs["instances"].pred_classes)
    print(outputs["instances"].pred_boxes)

    v = Visualizer(picture[:,:, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

    cv2.imwrite(output_path + element[:-4] + "_with_detections.jpg", out.get_image()[:, :, ::-1])
# Out:
# tensor([ 0, 74], device='cuda:0')
# Boxes(tensor([[ 698.5547,  763.8758,  982.0164, 1008.8953],
#         [ 455.5566, 2651.2224,  955.9070, 2782.2634]], device='cuda:0'))
# tensor([ 0, 39], device='cuda:0')
# Boxes(tensor([[ 901.3246,  395.9820, 1809.4486, 1412.7573],
#         [ 894.7195,  273.8697, 1574.4403, 1272.6602]], device='cuda:0'))
# tensor([ 0, 56, 56], device='cuda:0')
# Boxes(tensor([[ 908.0658,  783.4536, 1665.7925, 1536.8015],
#         [ 833.0997,  934.5188, 1797.1232, 1531.7794],
#         [1241.9440, 1006.5624, 1825.4373, 1525.5188]], device='cuda:0'))
# tensor([0], device='cuda:0')
# Boxes(tensor([[ 576.1794,  638.9583, 1276.1205, 2511.9189]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([14, 74], device='cuda:0')
# Boxes(tensor([[ 314.9431, 1109.9380, 1170.3762, 2046.4963],
#         [ 458.7278, 2645.9070,  938.2762, 2781.5947]], device='cuda:0'))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 771.0579,  570.3151, 1819.2838, 1501.9635]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 455.5171, 2649.4341,  960.4384, 2781.0447]], device='cuda:0'))
# tensor([73], device='cuda:0')
# Boxes(tensor([[  69.4291,  303.8414, 1547.1552, 2376.1812]], device='cuda:0'))
# tensor([ 0,  0, 73, 74], device='cuda:0')
# Boxes(tensor([[1072.2213, 1532.2266, 1205.8776, 1781.5204],
#         [ 446.8149, 1856.9581,  523.8593, 1998.6897],
#         [ 119.0797,  149.8119, 1690.6938, 2578.0078],
#         [ 455.0551, 2649.8672,  959.7955, 2780.5684]], device='cuda:0'))
# tensor([73], device='cuda:0')
# Boxes(tensor([[ 185.5756,  715.4671,  518.6399, 2138.0464]], device='cuda:0'))
# tensor([ 0, 35], device='cuda:0')
# Boxes(tensor([[1003.9100,  948.6546, 1314.9337, 1418.6237],
#         [ 540.3080, 1298.2659,  810.6604, 1588.4783]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([11], device='cuda:0')
# Boxes(tensor([[ 108.7686,  398.7916, 1536.6572, 2351.3425]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([33, 33, 33], device='cuda:0')
# Boxes(tensor([[ 711.5024, 1084.9626, 1387.8707, 1612.4482],
#         [1225.8169, 1270.4636, 1510.8303, 1481.9166],
#         [1272.7438, 1464.1199, 1566.2117, 1615.0553]], device='cuda:0'))
# tensor([14, 16, 74], device='cuda:0')
# Boxes(tensor([[ 242.2244,  699.3130, 1202.5765, 2094.3452],
#         [ 222.8562,  605.6424, 1178.3945, 2096.5422],
#         [ 461.9600, 2649.3464,  938.0266, 2782.1636]], device='cuda:0'))
# tensor([22, 22, 74], device='cuda:0')
# Boxes(tensor([[ 317.7243, 1070.4749,  967.9346, 1822.4194],
#         [ 561.1653, 1082.7070,  756.1854, 1355.7588],
#         [ 462.4481, 2649.4897,  935.8884, 2782.1267]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 461.7824, 2648.7402,  934.2667, 2782.1582]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 455.1556, 2650.3320,  957.6344, 2780.4565]], device='cuda:0'))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 452.4837, 2649.9758,  960.0368, 2778.6570]], device='cuda:0'))
# tensor([16, 74], device='cuda:0')
# Boxes(tensor([[ 126.1014, 1391.5447,  530.9446, 1825.8950],
#         [ 461.1699, 2648.2363,  936.0784, 2781.3521]], device='cuda:0'))
# tensor([74, 75, 77], device='cuda:0')
# Boxes(tensor([[ 460.8641, 2647.6599,  935.8635, 2782.1101],
#         [ 138.3644,  704.7499, 1550.1382, 2375.7625],
#         [  54.6949,  408.9068, 1526.6909, 2425.9163]], device='cuda:0'))
# tensor([0], device='cuda:0')
# Boxes(tensor([[ 565.0539,  805.5366, 1091.5146, 1720.1017]], device='cuda:0'))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 461.1327, 2648.3186,  935.3538, 2781.7664]], device='cuda:0'))
# tensor([25], device='cuda:0')
# Boxes(tensor([[ 213.3170, 1352.8632, 1259.2162, 1991.1664]], device='cuda:0'))
# tensor([ 0,  0,  0, 73], device='cuda:0')
# Boxes(tensor([[1397.6415, 1403.4196, 1513.8981, 1534.7179],
#         [1395.4866,  219.7081, 1443.0200,  333.7434],
#         [1450.3693,  211.0542, 1500.3433,  358.7583],
#         [1379.5162, 1256.0258, 1662.3390, 1695.0050]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 456.1640, 2649.4326,  960.0838, 2781.1929]], device='cuda:0'))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 453.1138, 1004.6395, 1208.2081, 1770.9164]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([62, 74], device='cuda:0')
# Boxes(tensor([[  94.7207,  443.3529, 1571.0891, 1771.1715],
#         [ 455.3984, 2650.3735,  955.0471, 2780.7786]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([16], device='cuda:0')
# Boxes(tensor([[ 741.6342, 1316.1108, 1852.5115, 2619.1917]], device='cuda:0'))
# tensor([74], device='cuda:0')
# Boxes(tensor([[ 462.4192, 2649.1316,  935.1417, 2781.9329]], device='cuda:0'))
# tensor([32], device='cuda:0')
# Boxes(tensor([[ 907.6824, 1069.1674,  949.2280, 1106.8458]], device='cuda:0'))
# tensor([32], device='cuda:0')
# Boxes(tensor([[ 909.9237, 1067.1454,  951.8555, 1108.4852]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([0, 0], device='cuda:0')
# Boxes(tensor([[ 628.2551,  594.6830, 2821.9385, 5387.3232],
#         [ 695.9248, 4426.0635,  874.8297, 4707.8335]], device='cuda:0'))
# tensor([0, 0], device='cuda:0')
# Boxes(tensor([[1060.6997,  743.3008, 1380.9545, 1157.0300],
#         [1249.0028,  765.5035, 1604.6294, 1194.1268]], device='cuda:0'))
# tensor([0], device='cuda:0')
# Boxes(tensor([[1291.1959,  328.3414, 1424.4840,  511.8800]], device='cuda:0'))
# tensor([ 0,  0, 74, 25], device='cuda:0')
# Boxes(tensor([[ 188.2592, 1377.0083, 1440.9672, 2396.4199],
#         [ 666.8778,  594.1408,  844.3401, 1056.4988],
#         [ 454.7204, 2650.8811,  953.9599, 2780.2002],
#         [ 759.1050,  986.9387,  856.9879, 1507.4292]], device='cuda:0'))
# tensor([ 0,  2,  0,  3,  0,  0,  0,  0,  0,  0,  0,  0,  0, 56,  0,  0],
#        device='cuda:0')
# Boxes(tensor([[ 149.7628, 1887.8495,  299.1752, 2075.3022],
#         [1055.1254,  943.2997, 1155.4269, 1019.8007],
#         [1362.3037, 1656.7152, 1529.6382, 1859.2430],
#         [ 263.2081,  896.7516,  460.6180, 1053.4235],
#         [1064.1647, 2186.7500, 1127.2432, 2313.5571],
#         [1040.8455, 1400.0466, 1102.5464, 1605.6991],
#         [1360.1100, 1117.1974, 1479.1595, 1298.7944],
#         [ 719.6578,  868.1268,  821.7109, 1048.4529],
#         [ 903.2672, 2125.0059,  985.6642, 2318.6184],
#         [ 372.0435, 1875.8862,  477.7389, 2073.5850],
#         [ 589.7850, 1467.9568,  807.1169, 1834.4541],
#         [1338.5193, 1426.0995, 1470.2872, 1624.7549],
#         [ 589.2081,  890.2252,  731.9223, 1027.5336],
#         [ 931.1885, 1610.2576, 1136.0371, 1838.6730],
#         [ 712.3897, 1470.1210,  824.2514, 1603.7319],
#         [1305.4360, 1703.7449, 1396.0404, 1854.8309]], device='cuda:0'))
# tensor([ 0, 74], device='cuda:0')
# Boxes(tensor([[ 478.2427,  759.6223, 1142.3145, 1708.9321],
#         [ 455.8128, 2650.9980,  959.1013, 2781.1877]], device='cuda:0'))
# tensor([56, 56, 56, 74], device='cuda:0')
# Boxes(tensor([[1081.9150, 1209.1934, 1375.1826, 1588.2329],
#         [1347.6462, 1207.6870, 1580.9303, 1512.4540],
#         [ 481.1053, 1192.2234,  781.0412, 1536.0172],
#         [ 454.6511, 2649.5615,  958.4670, 2779.9646]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([73], device='cuda:0')
# Boxes(tensor([[ 253.3229,  823.5080,  967.6143, 1860.0795]], device='cuda:0'))
# tensor([31], device='cuda:0')
# Boxes(tensor([[ 139.4070, 1730.4982,  404.9398, 1871.3892]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([60, 56, 74], device='cuda:0')
# Boxes(tensor([[ 104.1984, 2014.4543, 1527.6050, 2335.9045],
#         [ 557.7153, 1530.4576, 1085.2225, 2050.6724],
#         [ 455.8329, 2650.4341,  955.9166, 2779.8108]], device='cuda:0'))
# tensor([14], device='cuda:0')
# Boxes(tensor([[ 865.9384,  665.7466, 1424.2206, 1311.1693]], device='cuda:0'))
# tensor([73, 73], device='cuda:0')
# Boxes(tensor([[ 846.2220,   36.7745, 1012.4279, 1404.1294],
#         [1544.2434,  567.3983, 1720.9259,  686.0348]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([73], device='cuda:0')
# Boxes(tensor([[ 191.0897,  200.8343, 1735.4353, 2526.6292]], device='cuda:0'))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
# tensor([], device='cuda:0', dtype=torch.int64)
# Boxes(tensor([], device='cuda:0', size=(0, 4)))
